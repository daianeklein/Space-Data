# %%
# importacao da biblioteca
import pandas as pd

# %%
#importacao do dataset

url = 'https://raw.githubusercontent.com/daianeklein/Space-Data/main/happiness_dataset.csv'

df = pd.read_csv(url)

# %%
# visulizacao rapida do dataset

df.shape #tamanho do dataset
# Out:
# (153, 20)

# %%
# head

df.head() #por default, 5 primeiros registros
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
df.head(10) #10 primeiros registros
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe        7.8087
# 1      Denmark         Western Europe        7.6456
# 2  Switzerland         Western Europe        7.5599
# 3      Iceland         Western Europe        7.5045
# 4       Norway         Western Europe        7.4880
# 5  Netherlands         Western Europe        7.4489
# 6       Sweden         Western Europe        7.3535
# 7  New Zealand  North America and ANZ        7.2996
# 8      Austria         Western Europe        7.2942
# 9   Luxembourg         Western Europe        7.2375
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
# ...

# %%
#tail

df.tail() #por default, 5 ultimos registros
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                        0.115183      3.701658      3.250141
# 149                        0.052425      3.415053      3.209547
# 150                        0.058674      3.414202      3.184198
# 151                        0.107610      3.027516      2.605684
# 152                        0.031311      2.628270      2.505530
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 148               6.625160        0.319460                45.200001
# ...

# %%
df.tail(10) #10 ultimos registros
# Out:
#                  Country name            Regional indicator  Ladder score  \
# 143                     India                    South Asia        3.5733
# 144                    Malawi            Sub-Saharan Africa        3.5380
# 145                     Yemen  Middle East and North Africa        3.5274
# 146                  Botswana            Sub-Saharan Africa        3.4789
# 147                  Tanzania            Sub-Saharan Africa        3.4762
# 148  Central African Republic            Sub-Saharan Africa        3.4759
# 149                    Rwanda            Sub-Saharan Africa        3.3123
# 150                  Zimbabwe            Sub-Saharan Africa        3.2992
# 151               South Sudan            Sub-Saharan Africa        2.8166
# 152               Afghanistan                    South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 143                        0.027702      3.627596      3.519003
# ...

# %%
# sample

df.sample() #default == 1 aleatorio
# Out:
#    Country name          Regional indicator  Ladder score  \
# 78      Croatia  Central and Eastern Europe        5.5047
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 78                        0.037784      5.578756      5.430644
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 78              10.070875        0.874624                70.214905
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 78                      0.714839   -0.128538                   0.916495
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 78                  1.972317                          1.109024
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 78                      1.311265                               0.900576
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 78                                    0.381457                  0.113999
#
# ...

# %%
df.sample(5) #5 registros aleatorios
# Out:
#     Country name           Regional indicator  Ladder score  \
# 129    Sri Lanka                   South Asia        4.3270
# 104      Albania   Central and Eastern Europe        4.8827
# 8        Austria               Western Europe        7.2942
# 135     Ethiopia           Sub-Saharan Africa        4.1862
# 45     Nicaragua  Latin America and Caribbean        6.1371
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 129                        0.053086      4.431048      4.222952
# 104                        0.056116      4.992687      4.772713
# 8                          0.033365      7.359596      7.228804
# 135                        0.038915      4.262474      4.109927
# 45                         0.063887      6.262319      6.011882
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 129               9.389970        0.825374                67.200066
# 104               9.417931        0.671070                68.708138
# ...

# %%
df.sample(5) #5 registros aleatorios
# Out:
#     Country name           Regional indicator  Ladder score  \
# 40     Lithuania   Central and Eastern Europe        6.2155
# 100      Senegal           Sub-Saharan Africa        4.9808
# 132      Myanmar               Southeast Asia        4.3080
# 90         Ghana           Sub-Saharan Africa        5.1480
# 59       Jamaica  Latin America and Caribbean        5.8898
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 40                         0.044193      6.302118      6.128881
# 100                        0.052769      5.084228      4.877373
# 132                        0.042949      4.392180      4.223820
# 90                         0.058635      5.262924      5.033076
# 59                         0.120590      6.126157      5.653443
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 40               10.343626        0.926107                67.294075
# 100               8.118982        0.723616                59.599152
# ...

# %%
df.sample(frac = 0.05) # 5% do dataframe
# Out:
#                 Country name                  Regional indicator  \
# 113                     Mali                  Sub-Saharan Africa
# 29                     Italy                      Western Europe
# 69                   Moldova  Commonwealth of Independent States
# 124  Palestinian Territories        Middle East and North Africa
# 104                  Albania          Central and Eastern Europe
# 128               Mauritania                  Sub-Saharan Africa
# 101                   Guinea                  Sub-Saharan Africa
# 111             Burkina Faso                  Sub-Saharan Africa
#
#      Ladder score  Standard error of ladder score  upperwhisker  lowerwhisker  \
# 113        4.7293                        0.064363      4.855451      4.603149
# 29         6.3874                        0.043288      6.472245      6.302556
# 69         5.6075                        0.042276      5.690360      5.524640
# ...

# %%
df.sample(3, random_state = 3)
# Out:
#    Country name            Regional indicator  Ladder score  \
# 47       Kuwait  Middle East and North Africa        6.1021
# 3       Iceland                Western Europe        7.5045
# 31       Brazil   Latin America and Caribbean        6.3756
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 47                        0.053298      6.206563      5.997636
# 3                         0.059616      7.621347      7.387653
# 31                        0.040791      6.455550      6.295650
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 47              11.089825        0.846475                66.767647
# 3               10.772559        0.974670                73.000000
# 31               9.566435        0.896724                66.480164
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 47                      0.872366   -0.100185                   0.760849
# ...

# %%
df.sample(3, random_state = 3)
# Out:
#    Country name            Regional indicator  Ladder score  \
# 47       Kuwait  Middle East and North Africa        6.1021
# 3       Iceland                Western Europe        7.5045
# 31       Brazil   Latin America and Caribbean        6.3756
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 47                        0.053298      6.206563      5.997636
# 3                         0.059616      7.621347      7.387653
# 31                        0.040791      6.455550      6.295650
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 47              11.089825        0.846475                66.767647
# 3               10.772559        0.974670                73.000000
# 31               9.566435        0.896724                66.480164
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 47                      0.872366   -0.100185                   0.760849
# ...

# %%
df.sample(3, random_state = 4)
# Out:
#        Country name          Regional indicator  Ladder score  \
# 46          Romania  Central and Eastern Europe        6.1237
# 18   Czech Republic  Central and Eastern Europe        6.9109
# 133         Comoros          Sub-Saharan Africa        4.2886
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 46                         0.047433      6.216668      6.030732
# 18                         0.042891      6.994967      6.826833
# 133                        0.084340      4.453907      4.123293
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 46               10.107584        0.825162                67.207237
# 18               10.404163        0.914431                70.047935
# 133               7.833630        0.625662                57.349010
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 46                       0.842823   -0.197815                   0.934300
# ...

# %%
df.sample(3, random_state = 3).T
# Out:
#                                                                       47  \
# Country name                                                      Kuwait
# Regional indicator                          Middle East and North Africa
# Ladder score                                                      6.1021
# Standard error of ladder score                                 0.0532977
# upperwhisker                                                     6.20656
# lowerwhisker                                                     5.99764
# Logged GDP per capita                                            11.0898
# Social support                                                  0.846475
# Healthy life expectancy                                          66.7676
# Freedom to make life choices                                    0.872366
# Generosity                                                     -0.100185
# Perceptions of corruption                                       0.760849
# ...

# %%
df.head().T
# Out:
#                                                          0               1  \
# Country name                                       Finland         Denmark
# Regional indicator                          Western Europe  Western Europe
# Ladder score                                        7.8087          7.6456
# Standard error of ladder score                   0.0311563       0.0334923
# upperwhisker                                       7.86977         7.71124
# lowerwhisker                                       7.74763         7.57996
# Logged GDP per capita                              10.6393          10.774
# Social support                                     0.95433        0.955991
# Healthy life expectancy                            71.9008         72.4025
# Freedom to make life choices                      0.949172        0.951444
# Generosity                                       -0.059482       0.0662018
# ...
